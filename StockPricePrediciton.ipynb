# %% [markdown]
# <a href="https://colab.research.google.com/github/mx010xm/hello-world/blob/master/StockPricePrediciton.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Install the dependencies
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
plt.style.use('bmh')

# %%
#Load the data
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ee617fac-cd31-446a-bba7-0fe735860396" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ee617fac-cd31-446a-bba7-0fe735860396">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving SASA-ClosingPrice-Data.csv to SASA-ClosingPrice-Data.csv

# %%
#Store the data into a data frame
df = pd.read_csv('SASA-ClosingPrice-Data.csv')
df.head(6)
# Out:
#         Tarih   Şimdi  Açılış  Yüksek   Düşük    Hac.  Fark %
# 0  01.07.2020  11,010  10,840  11,160  10,800  32,02M   1,94%
# 1  30.06.2020  10,800  10,820  10,910  10,760  11,20M   0,19%
# 2  29.06.2020  10,780  10,760  10,850  10,660   8,22M   0,09%
# 3  26.06.2020  10,770  10,870  10,990  10,770  14,10M  -0,65%
# 4  25.06.2020  10,840  10,570  10,840  10,570  16,01M   2,65%
# 5  24.06.2020  10,560  10,750  10,950  10,550  15,42M  -1,77%

# %%
#Get the number of trading days
df.shape
# Out:
# (251, 7)

# %%
#Visualize the close price data
plt.figure(figsize=(64,32))
plt.title('Sasa')
plt.xlabel('Days')
plt.ylabel('Closing Price (TL)')
plt.plot(df['Açılış'])
plt.show()
